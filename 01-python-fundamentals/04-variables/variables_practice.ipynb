# %% [markdown]
# Exercise 1
#
# Create variables for:
#
# Your name
# Your age
# Your city
#
# Print all three.

# %%
student_name = "Vinod Kumar Kasipuri"
student_age  =  35
student_city = "Hyd"

print("------ My Profile ------")
print("Name :", student_name)
print("Age  :", student_age)
print("City :", student_city)
# Out:
# ------ My Profile ------
# Name : Vinod Kumar Kasipuri
# Age  : 35
# City : Hyd

# %% [markdown]
# Exercise 2
#
# Task
#
# Create variables for:
#
# - Favorite food
# - Favorite color
# - Favorite movie
#
# Print them.

# %%
favorite_food  = "Hyderabad Biryani"
favorite_color = "Black" 
favorite_movie = "OG"

print("--------My Favorite Things----------")

print("My Favorite Food :",  favorite_food)
print("My Favorite Color:", favorite_color)
print("My Favorite Movie:", favorite_movie)
# Out:
# --------My Favorite Things----------
# My Favorite Food : Hyderabad Biryani
# My Favorite Color: Black
# My Favorite Movie: OG

# %% [markdown]
# Exercise 3
#
# Task
#
# Create variables for:
#
# - Laptop Brand
# - RAM
# - Price
#
# Expected Output
#
# ```text
# ------ Laptop Details ------
#
# Brand :
# RAM   :
# Price :
# ```

# %%
lap_top_brand = "Dell"
ram           =  16
price         =  65000


print("------ Laptop Details ------")

print("Brand :", lap_top_brand)
print("RAM   :", ram , "GB")
print("Price : ₹",price)
# Out:
# ------ Laptop Details ------
# Brand : Dell
# RAM   : 16 GB
# Price : ₹ 65000

# %% [markdown]
# Exercise 4
#
# Task
#
# Create variables for:
#
# - Friend Name
# - Friend Age
# - Friend City
#
# Expected Output
#
# ```text
# ------ Friend Details ------
#
# Name :
# Age  :
# City :
# ```

# %%
friend_name = "Sandeep"
friend_age  = 33
friend_city = "Hyderabad"


print("----- Friend Details ------")

print("Name :", friend_name)
print("Age  :", friend_age)
print("City :", friend_city)
# Out:
# ----- Friend Details ------
# Name : Sandeep
# Age  : 33
# City : Hyderabad

# %% [markdown]
# Exercise 5
#
# Task
#
# Create variables for:
#
# - Course Name
# - Course Duration
# - Trainer Name
#
# Expected Output
#
# ```text
# ------ Course Details ------
#
# Course Name     :
# Course Duration :
# Trainer Name    :
# ```

# %%
course_name = "Python"
course_duration = 35 
trainer_name = "Vinod Kumar Kasipuri"


print("------- Course Details -------")

print("Course Name     :", course_name )
print("Course Duration :", course_duration, "Hours")
print("Trainer Name    :", Trainer_name)
# Out:
# ------- Course Details -------
# Course Name     : Python
# Course Duration : 35 Hours
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 10
#       6 print("------- Course Details -------")
#       7
#       8 print("Course Name     :", course_name )
#       9 print("Course Duration :", course_duration, "Hours")
# ---> 10 print("Trainer Name    :", Trainer_name)
#      11
#      12
#      13
#
# NameError: name 'Trainer_name' is not defined

# %% [markdown]
# ## Exercise 6
#
# ### Task
#
# Create variables for:
#
# - Car Brand
# - Car Model
# - Car Year
# - Car Color
#
# Expected Output
#
# ```text
# ------ Car Details ------
#
# Brand :
# Model :
# Year  :
# Color :
# ```

# %%
car_brand = "Maruti"
car_model =  "ZN"
car_year  = 2026
car_color = "Black"


print("------- Car Details -------")

print("Car Brand : " , car_brand)
print("Car Model : " , car_model)
print("Car Year  : " , car_year)
print("Car Color : " , car_color)
# Out:
# ------- Car Details -------
# Car Brand :  Maruthi
# Car Model :  ZN
# Car Year  :  2026
# Car Color :  Black

# %% [markdown]
# ## Exercise 7
#
# ### Task
#
# Create variables for:
#
# - Mobile Brand
# - Mobile Model
# - Mobile Price
# - Mobile Storage
#
# Expected Output
#
# ```text
# ------ Mobile Details ------
#
# Brand   :
# Model   :
# Price   :
# Storage :

# %%
mobile_brand = "Apple"
mobile_model = "iPhone 14 Pro"
mobile_price = 200000
mobile_storage = 250

print("------ Mobile Details ------")

print("Brand   :", mobile_brand)
print("Model   :", mobile_model)
print("Price   : ₹", mobile_price)
print("Storage :", mobile_storage, "GB")
# Out:
# ------ Mobile Details ------
# Brand   : Apple
# Model   : iPhone 14 Pro
# Price   : ₹ 200000
# Storage : 250 GB

# %% [markdown]
# ## Exercise 8
#
# ### Task
#
# Create variables for:
#
# - Bank Name
# - Branch Name
# - Account Type
# - Account Balance
#
# Expected Output
#
# ```text
# ------ Bank Account Details ------
#
# Bank Name       :
# Branch Name     :
# Account Type    :
# Account Balance :
# ```

# %%
bank_name = "SBI"
branch_name = "Hyderabad"
account_type = "Personal Account"
account_balance = 300000


print("------ Bank Account Details ------")

print("Bank Name       : " , bank_name )
print("Branch Name     : " , branch_name)
print("Account Type    : " , account_type)
print("Account Balance : " , account_balance)
# Out:
# ------ Bank Account Details ------
# Bank Name       :  SBI
# Branch Name     :  Hyderabad
# Account Type    :  Personal Account
# Account Balance :  300000
